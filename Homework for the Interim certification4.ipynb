# %%
from openai import OpenAI

# %%
client = OpenAI(api_key="sk-ea349f083ce64692ba6294f465ec0132", base_url="https://api.deepseek.com/v1")

# %%
response = client.chat.completions.create(
    model="deepseek-coder",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "Пожалуйста, объясни мне, как работают алгоритмы сортировки. Какие шаги алгоритмов включают? Как они сравнивают элементы?"},
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# Вот базовые шаги сортировок:
#
# 1. **Сравнение двух элементов**: Алгоритмы сортировки сравнивают два соседних элемента и меняют их местами, если порядок не соответствует желаемому (например, по возрастанию или убыванию).
#
# 2. **Перемещение по списку**: При этом они сканируют весь список, сравнивая каждый элемент с соседним, пока все элементы не будут отсортированы по нужным критериям.
#
# 3. **Повторение процесса**: После первой прохода по списку наибольший (или наименьший) элемент будет находиться в его конец. Для полного отсортированного списка нужно пройти по нему ещё несколько раз.
#
# Такие алгоритмы включают в себя:
#
# - **Сортировка выбором (Selection Sort)**: Находит наименьший элемент в массиве и помещает его на первую позицию. Затем находит следующий наименьший элемент и ставит его на вторую позицию, и так далее, пока весь массив не будет отсортирован.
#
# ...

# %%
# Чтобы получить более полезный результат от модели, можно попробовать следующие идеи:

# Уточнение запроса: Нужно убедиться, что запрос ясен и конкретен. Если задается общий вопрос, модель ответит на него, но если нужно узнать о чем то более конкретном, нужно это уточнить в вопросе.

# Использование конкретных примеров: Можно дать примеры, которые помогут понять алгоритм. Например, "Пожалуйста, объясни мне, как работает алгоритм быстрой сортировки. Можете показать, как он сравнивает элементы и как он рекурсивно разделяет массив?"

# Формулировка вопроса в терминах программирования: Если задаются вопросы о программировании, нужно использовать термины, что широко распространены в этой области. Например, "Как выглядит код быстрой сортировки на Python?"

# Делать запрос на конкретный язык программирования: Если вы работаете с конкретным языком программирования, нужно это уточнять. Например, "Как выглядит код быстрой сортировки на C++?"

# Делать запрос на конкретную реализацию: Если вы хотите увидеть конкретную реализацию алгоритма сортировки, нужно уточнять об этом. Например, "Предоставьте пример кода быстрой сортировки на Python."

# Делать запрос на объяснение шагов алгоритма: Если необходимо понять подробную работу алгоритма, можно запросить разбор его действий пошагово. Например, "Пожалуйста, объясни мне шаги алгоритма быстрой сортировки."

# Делать запрос на визуализацию: Если вы хотите видеть визуализацию алгоритма, запросите это. Например, "Можете показать визуализацию работы алгоритма быстрой сортировки на массиве [5, 3, 8, 4, 2]?"

# Делать запрос на сравнение с другими алгоритмами: Если вы хотите сравнить быструю сортировку с другими алгоритмами сортировки,нужно уточнять это в запросе. Например, "Как быстрая сортировка сравнима с другими алгоритмами сортировки, такими как сортировка пузырьком или сортировка вставками?"

# %%
"Вот пример более эффективного кода:"
response = client.chat.completions.create(
    model="deepseek-coder",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "Объясни, как работает алгоритм быстрой сортировки. Покажи, как он сравнивает элементы и как он рекурсивно разделяет массив на питоне? А так же скажи чем методы сортировки отличаются друг от друга и дай примеры кода разных видов сортировки на питоне"},
    ]
)

print(response.choices[0].message.content)
# Out:
# Алгоритм быстрой сортировки, также известный как quicksort, является одним из самых эффективных алгоритмов сортировки. Он основан на принципе "разделяй и властвуй", в котором массив или список разделяется на две части опорного элемента, и каждая из этих частей сортируется рекурсивно.
#
# Вот простой пример реализации quicksort на Python:
#
# ```python
# def quicksort(arr):
#     if len(arr) <= 1:
#         return arr
#     pivot = arr[len(arr) // 2]
#     left = [x for x in arr if x < pivot]
#     middle = [x for x in arr if x == pivot]
#     right = [x for x in arr if x > pivot]
#     return quicksort(left) + middle + quicksort(right)
# ```
#
# Рабочий процесс quicksort:
#
# 1. Выбирается элемент из массива. Этот элемент называется опорным. В примере он выбирается как средний элемент.
# 2. Из массива удаляются все элементы, которые меньше опорного, и оставшиеся элементы двигаются влево.
# ...
