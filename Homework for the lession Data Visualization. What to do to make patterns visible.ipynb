# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df =pd.read_csv(r"C:\Users\kir4i\Downloads\Telegram Desktop\3.1 dataset.csv")

# %%
# Построение двумерной гистограммы
plt.hist2d(df['x'], df['y'], bins=50, cmap='viridis')
plt.colorbar(label='Counts')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('2D гистограмма of X and Y')
plt.show()
